# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('sample_1.png')
image = cv2.resize(image, (224,224))

# %%
roi_array = np.array(image) / 255.0
roi_array = np.expand_dims(roi_array, axis=0)
pred = video_model.predict(roi_array)

print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.9841579]]

# %%
pred
# Out:
# array([[0.9760801]], dtype=float32)

# %%
roi_array.shape
# Out:
# (1, 224, 224, 3)

# %%
plt.imshow(image)

# %%
plt.imshow(image)

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
import cv2

# %%
img = cv2.imread('static/spectograms/sample_3.wav.png')

# %%
img.shape
# Out:
# (616, 930, 3)

# %%
616*2
# Out:
# 1232

# %%
930*2
# Out:
# 1860

# %%
cv2.imwrite()
